# %% [markdown]
# # Sample:
#
# ## Use your code from the companion `stitches` package:
#
# ### Import the necessary Python packages

# %%
# this tells jupyter you want to see what you are plotting in the output cell
# %matplotlib inline

# our python package
import stitches

# %% [markdown]
# ### Plot a picture of my dog Ava

# %%
# plot Ava
stitches.plot_my_dog()
